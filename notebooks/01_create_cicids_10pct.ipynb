# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

# %%
DATA_PATH = r"D:\Coding\VanetUAV\data\processed\cicids_v1_raw.csv"

df = pd.read_csv(DATA_PATH)

df.shape
# Out:
# (2830743, 83)

# %%
if "label_bin" not in df.columns:
    df["label_bin"] = (df["Label"] != "BENIGN").astype(int)

df["label_bin"].value_counts(), df["label_bin"].value_counts(normalize=True)
# Out:
# (label_bin
#  0    2273097
#  1     557646
#  Name: count, dtype: int64,
#  label_bin
#  0    0.803004
#  1    0.196996
#  Name: proportion, dtype: float64)

# %%
df["Label"].value_counts(normalize=True)
# Out:
# Label
# BENIGN                        0.803004
# DoS Hulk                      0.081630
# PortScan                      0.056144
# DDoS                          0.045227
# DoS GoldenEye                 0.003636
# FTP-Patator                   0.002804
# SSH-Patator                   0.002083
# DoS slowloris                 0.002048
# DoS Slowhttptest              0.001943
# Bot                           0.000695
# Web Attack � Brute Force      0.000532
# Web Attack � XSS              0.000230
# Infiltration                  0.000013
# Web Attack � Sql Injection    0.000007
# Heartbleed                    0.000004
# Name: proportion, dtype: float64

# %%
RANDOM_STATE = 42

df_10pct, _ = train_test_split(
    df,
    test_size=0.90,               # keep 10%
    stratify=df["label_bin"],     # preserve ratio
    random_state=RANDOM_STATE
)

df_10pct.shape
# Out:
# (283074, 84)

# %%
print("FULL DATASET")
print(df["label_bin"].value_counts(normalize=True))

print("\n10% DATASET")
print(df_10pct["label_bin"].value_counts(normalize=True))
# Out:
# FULL DATASET
# label_bin
# 0    0.803004
# 1    0.196996
# Name: proportion, dtype: float64
#
# 10% DATASET
# label_bin
# 0    0.803002
# 1    0.196998
# Name: proportion, dtype: float64

# %%
comparison = pd.concat(
    [
        df["Label"].value_counts(normalize=True),
        df_10pct["Label"].value_counts(normalize=True)
    ],
    axis=1,
    keys=["full_dataset", "10pct_dataset"]
).fillna(0)

comparison
# Out:
#                             full_dataset  10pct_dataset
# Label
# BENIGN                          0.803004       0.803002
# DoS Hulk                        0.081630       0.081491
# PortScan                        0.056144       0.056353
# DDoS                            0.045227       0.045077
# DoS GoldenEye                   0.003636       0.003646
# FTP-Patator                     0.002804       0.002692
# SSH-Patator                     0.002083       0.002187
# DoS slowloris                   0.002048       0.002028
# DoS Slowhttptest                0.001943       0.002067
# Bot                             0.000695       0.000742
# Web Attack � Brute Force        0.000532       0.000488
# Web Attack � XSS                0.000230       0.000205
# Infiltration                    0.000013       0.000014
# Web Attack � Sql Injection      0.000007       0.000011
# Heartbleed                      0.000004       0.000000

# %%
cols_to_check = [
    "Flow Duration",
    "Total Fwd Packets",
    "Total Backward Packets",
    "Packet Length Mean"
]

df[cols_to_check].describe(percentiles=[.05, .5, .95])
# Out:
#        Flow Duration  Total Fwd Packets  Total Backward Packets  \
# count   2.830743e+06       2.830743e+06            2.830743e+06
# mean    1.478566e+07       9.361160e+00            1.039377e+01
# std     3.365374e+07       7.496728e+02            9.973883e+02
# min    -1.300000e+01       1.000000e+00            0.000000e+00
# 5%      4.000000e+00       1.000000e+00            0.000000e+00
# 50%     3.131600e+04       2.000000e+00            2.000000e+00
# 95%     1.011146e+08       1.900000e+01            1.700000e+01
# max     1.200000e+08       2.197590e+05            2.919220e+05
#
#        Packet Length Mean
# count        2.830743e+06
# mean         1.719444e+02
# std          3.054915e+02
# min          0.000000e+00
# 5%           0.000000e+00
# 50%          5.720000e+01
# 95%          9.174615e+02
# max          3.337143e+03

# %%
df_10pct[cols_to_check].describe(percentiles=[.05, .5, .95])
# Out:
#        Flow Duration  Total Fwd Packets  Total Backward Packets  \
# count   2.830740e+05      283074.000000           283074.000000
# mean    1.473259e+07           9.758099               10.961858
# std     3.357205e+07         838.130197             1131.551950
# min    -1.000000e+00           1.000000                0.000000
# 5%      4.000000e+00           1.000000                0.000000
# 50%     3.127150e+04           2.000000                2.000000
# 95%     1.009597e+08          19.000000               17.000000
# max     1.200000e+08      207964.000000           284602.000000
#
#        Packet Length Mean
# count       283074.000000
# mean           170.947655
# std            304.436024
# min              0.000000
# 5%               0.000000
# 50%             57.200000
# 95%            917.076923
# max           2595.555556

# %%
OUTPUT_PATH = r"D:\Coding\VanetUAV\data\processed\cicids_10pct_stratified.csv"

df_10pct.to_csv(OUTPUT_PATH, index=False)

print(f"Saved {df_10pct.shape[0]} rows to:")
print(OUTPUT_PATH)
# Out:
# Saved 283074 rows to:
# D:\Coding\VanetUAV\data\processed\cicids_10pct_stratified.csv

# %%
del df
import gc
gc.collect()
# Out:
# 0
